# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %% [raw]
# chatbot
# OCR
# text to speech
# speech to text
#
# speech rec

# %%
from nltk.chat.util import Chat, reflections

# %%
reflections
# Out:
# {'i am': 'you are',
#  'i was': 'you were',
#  'i': 'you',
#  "i'm": 'you are',
#  "i'd": 'you would',
#  "i've": 'you have',
#  "i'll": 'you will',
#  'my': 'your',
#  'you are': 'I am',
#  'you were': 'I was',
#  "you've": 'I have',
#  "you'll": 'I will',
#  'your': 'my',
#  'yours': 'mine',
#  'you': 'me',
#  'me': 'you'}

# %% [raw]
# pairs = ( (ques, (resp1,resp2)), (ques, (resp1,resp2)), (ques, (resp1,resp2)), .....)

# %%
pairs = (
    (r'i like (.*)', 
        (
            'Surely, you can like %1',
            'why, do you like %1?'
        )
    ),
    (r'will you please (.*)', 
        (
            'yeah, sure',
            'no, i can not do this'
        )
    ),
    (r'(.*)python(.*)',
         (
             'python is an interpreted language',
             'python is 4th generation language',
             'python is language of today and tomorrow'             
         )    
    )
)

# %%
cb = Chat(pairs, reflections)

# %%
cb

# %%
cb.converse()
# Out:
# > i dont know what to say
# None
# > i like mango juice
# Surely, you can like mango juice
# > i like kitkat
# why, do you like kitkat?
# > i like python programming
# Surely, you can like python programming
# > will you please tell me the time
# yeah, sure
# > will you please shut up
# yeah, sure
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-c456c24e660f> in <module>
# ----> 1 cb.converse()
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\chat\util.py in converse(self, quit)
#     117             user_input = quit
#     118             try:
# --> 119                 user_input = input(">")
#     120             except EOFError:
#     121                 print(user_input)
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
cb.respond('tell me about python')
# Out:
# 'python is 4th generation language'

# %%
qu = 'can python be used for machine learning'

# %%
resp = cb.respond(qu)

# %%
resp
# Out:
# 'python is language of today and tomorrow'

# %%
# !pip install pyttsx3
# Out:
# Requirement already satisfied: pyttsx3 in c:\programdata\anaconda3\lib\site-packages (2.90)
# Requirement already satisfied: comtypes; platform_system == "Windows" in c:\programdata\anaconda3\lib\site-packages (from pyttsx3) (1.1.7)
# Requirement already satisfied: pywin32; platform_system == "Windows" in c:\programdata\anaconda3\lib\site-packages (from pyttsx3) (227)
# Requirement already satisfied: pypiwin32; platform_system == "Windows" in c:\programdata\anaconda3\lib\site-packages (from pyttsx3) (223)

# %%
# !pip install SpeechRecognition
# Out:
# Requirement already satisfied: SpeechRecognition in c:\programdata\anaconda3\lib\site-packages (3.8.1)

# %%
import pyttsx3

# %%
speng = pyttsx3.init()

# %%
speng.setProperty('rate',120)

# %%
speng.say('hello I am speaking')
speng.runAndWait()

# %%
import speech_recognition as sr

# %%
r = sr.Recognizer()

# %%
import webbrowser as wb

# %%
wb.open_new('https://google.com/search?q=chatbot')
# Out:
# True

# %%
qq = 'i want to purchase mobile'

# %%
qq.split('purchase')[-1].strip()
# Out:
# 'mobile'

# %%
while True:
    with sr.Microphone() as source:
        r.adjust_for_ambient_noise(source)
        audio = r.listen(source)
        try:
            que = r.recognize_google(audio)
            if que == 'exit':
                break            
            print('you said:',que)
            resp = cb.respond(que)
            if resp:
                print('Bot:',resp)
                speng.say(resp)
                speng.runAndWait()
            else:
                if 'search' in que:
                    if 'chatbot' in que:
                        wb.open_new('https://google.com/search?q=chatbot')
                    elif 'games' in que:
                        wb.open_new('https://google.com/search?q=games')
                elif 'purchase' in que:
                    query = que.split('purchase')[-1].strip()
                    wb.open_new('https://flipkart.com/search?q={}'.format(query))            
            print('-'*20)
        except Exception as e:
            print('error')
            print(e)
# Out:
# you said: I want to purchase mobile
# --------------------
# you said: I want to purchase iPhone
# --------------------

# %%
# !pip install pytesseract
# Out:
# Requirement already satisfied: pytesseract in c:\programdata\anaconda3\lib\site-packages (0.3.7)
# Requirement already satisfied: Pillow in c:\programdata\anaconda3\lib\site-packages (from pytesseract) (7.2.0)

# %%
path = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
import pytesseract
from PIL import Image

# %%
pytesseract.pytesseract.tesseract_cmd = path

# %%
img = Image.open('Capture.PNG')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=619x259 at 0x1D6333E7F70>

# %%
text = pytesseract.image_to_string(img)
text
# Out:
# 'this is anything text\nand you can see its been\n\ndone or not\ni do not care\n\x0c'

# %%
print(text)
# Out:
# this is anything text
# and you can see its been
#
# done or not
# i do not care

# %%
img2 = Image.open('Capture2.PNG')
img2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=657x337 at 0x1D632894400>

# %%
text2 = pytesseract.image_to_string(img2)
print(text2)
# Out:
# Home > Mobiles & Ac... > Mobiles
# ‘Showing 1 - 24 of 285 results for “iPhone”
# SortBy Relevance Popularity Price-LowtoHigh Price-High to Low Newest First
#
# APPLE iPhone 12 (Blue, 128 GB)
# 5,351 Ratings & 440 Reviews
#
# 128. GB ROM
# » 15.49 cm (6.1 inch) Super Retina XDR Display
# 12MP + 12MP | 12MP Front Gamera
# ‘A14 Bionic Chip with Next Generation Neural Engine Processor
# Ceramic Shield
# IP68 Water Resistance
# All Screen OLED Display
# Brand Warranty for 1 Year
#
#
#
# ‘Add to Compare

# %%
Image.open('text-messages-that-will-make-her-want-you.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=700x450 at 0x1D6329699A0>

# %%
text3 = pytesseract.image_to_string(Image.open('text-messages-that-will-make-her-want-you.jpg'))
print(text3)
# Out:
# No one really
# believes an angel like
# you exists
#
# wedskenya.com
